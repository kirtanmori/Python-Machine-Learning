# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\Tejaswini Mori\Downloads\ML Project - Logistic Regression Titanic Survival U16955478860 (2).csv")

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.drop(data[data["Embarked"].isnull()].index,inplace=True)

# %%
data["Age"].mean()
# Out:
# 29.64209269662921

# %%
data["Age"]=data["Age"].fillna(30)

# %%
data["Age"].isnull().sum()
# Out:
# 0

# %%
data.drop("Ticket",axis=1,inplace=True)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
enc=LabelEncoder()

# %%
data[["Sex","Embarked"]]=data[["Sex","Embarked"]].apply(enc.fit_transform)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
data.drop(["Name","Cabin"],axis=1,inplace=True)

# %%
x=data.drop("Survived",axis=1)

# %%
y=data["Survived"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score,recall_score,f1_score,classification_report

# %%
confusion_matrix(y_test,model.predict(x_test))
# Out:
# array([[85, 20],
#        [31, 42]], dtype=int64)

# %%
print(classification_report(y_test,model.predict(x_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.81      0.77       105
#            1       0.68      0.58      0.62        73
#
#     accuracy                           0.71       178
#    macro avg       0.71      0.69      0.70       178
# weighted avg       0.71      0.71      0.71       178

# %%
print(accuracy_score(y_test,model.predict(x_test)))
print(precision_score(y_test,model.predict(x_test)))
print(recall_score(y_test,model.predict(x_test)))
print(f1_score(y_test,model.predict(x_test)))
# Out:
# 0.7134831460674157
# 0.6774193548387096
# 0.5753424657534246
# 0.6222222222222222

# %%
model.predict_proba(x_test)
# Out:
# array([[0.3591145 , 0.6408855 ],
#        [0.95533474, 0.04466526],
#        [0.11327947, 0.88672053],
#        [0.63854417, 0.36145583],
#        [0.40161205, 0.59838795],
#        [0.81283105, 0.18716895],
#        [0.82719984, 0.17280016],
#        [0.78472725, 0.21527275],
#        [0.30633712, 0.69366288],
#        [0.81801564, 0.18198436],
#        [0.51142685, 0.48857315],
#        [0.05977608, 0.94022392],
#        [0.28024725, 0.71975275],
#        [0.87616075, 0.12383925],
#        [0.28688596, 0.71311404],
#        [0.87661588, 0.12338412],
#        [0.38851842, 0.61148158],
#        [0.57857866, 0.42142134],
#        [0.7405976 , 0.2594024 ],
#        [0.15709405, 0.84290595],
#        [0.58804846, 0.41195154],
#        [0.08867794, 0.91132206],
#        [0.7906514 , 0.2093486 ],
#        [0.81196472, 0.18803528],
#        [0.8693655 , 0.1306345 ],
#        [0.88339521, 0.11660479],
#        [0.39755804, 0.60244196],
#        [0.82331312, 0.17668688],
# ...

# %%
model.feature_import
